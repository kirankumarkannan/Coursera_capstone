# %% [markdown]
# IBM Data Science Certificate - Final Capstone Project

# %%
import numpy as np
import pandas as pd

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
